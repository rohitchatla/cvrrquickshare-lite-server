# %%
# !pip install pycrypto

# %%
import os
# try block to handle exception
try:
    # take path of image as a input
    path = input(r'Enter path of Image : ')
      
    # taking encryption key as input
    key = int(input('Enter Key for encryption of Image : '))
      
    # print path of image file and encryption key that
    # we are using
    print('The path of file : ', path)
    print('Key for encryption : ', key)
      
    # open file for reading purpose
    fin = open(os.path.join(path), 'rb')
      
    # storing image data in variable "image"
    image = fin.read()
    fin.close()
    
#     print(image)
      
    # converting image into byte array to 
    # perform encryption easily on numeric data
    image = bytearray(image)
    
    print(image)
  
    # performing XOR operation on each value of bytearray
#     for index, values in enumerate(image):
#         image[index] = values ^ key
  
#     # opening file for writting purpose
#     fin = open(path, 'wb')
      
#     # writing encrypted data in image
#     fin.write(image)
#     fin.close()
#     print('Encryption Done...')
  
      
except Exception:
    print('Error caught : ', Exception._name_)
# Out:
# Enter path of Image : ./sample.jpg
# Enter Key for encryption of Image : 1234
# The path of file :  ./sample.jpg
# Key for encryption :  1234
# ...

# %%
print('hello')
# Out:
# hello

# %%
from Crypto.Cipher import AES
from Crypto import Random

# %%
AES.block_size
# Out:
# 16

# %%
Random.new().read(16)
# Out:
# b'\xe0\xc8\x94\xd1S\xb9\x1e\xa0H\x88\xa3\x8c\xedN\xdb\xd6'

# %%
Random
# Out:
# <module 'Crypto.Random' from 'c:\\users\\rohit\\appdata\\local\\programs\\python\\python37\\lib\\site-packages\\Crypto\\Random\\__init__.py'>

# %%
from os import urandom
type(urandom(16))
import chardet
the_encoding = chardet.detect(urandom(16))
the_encoding
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# input_file = open("./sample.jpg", 'rb')#encoding="utf16"
# input_data = input_file.read()
# input_file.close()
# type(input_data)
key = Random.new().read(AES.block_size)
iv = Random.new().read(AES.block_size)


cfb_cipher = AES.new(key, AES.MODE_CFB, iv)
enc_data = cfb_cipher.encrypt(b64Bytes)#input_data
enc_data

s_k=str(key)#key.decode()
s_v=str(iv)
print(key,iv)
print(str(key),str(iv))
# print(s_k.encode(),s_v.encode())
#print(bytes(s_k, 'ISO-8859-1'))
old=bytes(s_k, 'ISO-8859-1')

# type(enc_data)
# enc_data=str(enc_data)
# type(enc_data)
# enc_data.decode('cp1252')

# enc_file = open("encrypted.enc", "w")
# enc_file.write(enc_data)
# enc_file.close()
# Out:
# b'e\xd2\xd9\xa1H\xd7*s\xf0\x86j\xbdKZ\x8f4' b'\x11\x96\x1ar\xb2\xff\x1cF\x95\xc4\xd6\x84W4\xa8\x18'
# b'e\xd2\xd9\xa1H\xd7*s\xf0\x86j\xbdKZ\x8f4' b'\x11\x96\x1ar\xb2\xff\x1cF\x95\xc4\xd6\x84W4\xa8\x18'

# %%
c = old.decode('unicode-escape').encode('ISO-8859-1')
#c=decode('utf-8')
type(c)
# print(c)
type(c[2:-1])
# Out:
# bytes

# %%
import chardet
the_encoding = chardet.detect(key)
the_encoding
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
import json
import base64

# data = [0, 1, 0, 0, 83, 116, -10]
# dataStr = json.dumps(data)

# base64EncodedStr = base64.b64encode(enc_data.encode('utf-8'))
# print(base64EncodedStr)

#print('decoded', base64.b64decode(enc_data))#base64EncodedStr
base64.b64decode(enc_data)
# Out:
# b"\xc9o\xc1\x0c\x8d+p\xfb\xcd\xf5\x08\x82 {\xad\x9f\xdd\xcc-\x80\x0b!V<\x90\x17\xfc\x0b\xad\x02\xb5t\x9ce\xbe\xdf\xde!\xae+\x0b\x95N\x0e?\x82J43\xfa\xb7\xc7\xceU\t\xc5\xf6\xe2\xaf\x95c\xd9\x81\xd0Bp\xd5\x95\xc0\x83\x0f%\xc0\xb8\xd03\xa8\x04\x87\xb3\x06v\xe1/8'\xc4\xff\xd3J1\xc9@\xbb\x93d*K\xd6]n\xd2\x0c|\x06[X\x01\x8bs\xdf\xb6S\x00'\xcf\xde\x96>\x97\x03\xb8\xfe!cd\xe0\xe0\x8a\x1a\x84\x14\x8da\xa2.\\\xed\xaa\xd6l\xce\x13\x9b\xb6\xe5\xf9,7\xc3\xbf\xd5\x03\xed\x8c"

# %%
# enc_file2 = open("encrypted.enc")
# enc_data2 = enc_file2.read()
# enc_file2.close()

cfb_decipher = AES.new(key, AES.MODE_CFB, iv)
plain_data = cfb_decipher.decrypt(enc_data)
type(plain_data)
plain_data
# output_file = open("output.jpg", "w")
# output_file.write(plain_data)
# output_file.close()
# Out:
# b'data:image/jpeg;base64,...'

# %%
import base64
msg = base64.b64decode(plain_data)

# %%
msg
# Out:
# b'$R\x05\x08#u\x01\x06\xaa\xd8\x14wn\xbe9\xeb\xbf=\x081\x05\x18r\tI5\x15Yv\x19q\xd7\x9f\x82\x18\xa3\xb2\xdb\xaf\xc3\x1c\xb3\xc3P\x10j\xad\x81\xdd\x16\xeb\xe3\x9e\xbb\xf3\xd0\x83\x10Q\x87 \x94\x93QU\x97a\x97\x1dy\xf8!\x8a;-\xba\xfc1\xcb12[\xa3\x07\xf7\xda\x01\x18\x0f\x0cEV\xbc\xfe\xce4\xdb\xa1\xa9K\x18\x89\\Y\x96\xa7gO\x81\xf6p\x9b\x05r\xb8\xa2\xb0r\xfc\xd6a\x99\xb8\xb3\xd4a.\xc0 ?1\xb8\xf7\x90BM<@\xa7\xe1\x13\\\xe1\xbc;\x05\xbf\x89\xc0\xc5\xa4wV\x9f/c\xbd\x13^\x937\x04*\xd6\x95\x86ac\x04p/\xb2Q\x8a\xc7\t\x06\xe0(E\xc7:P\xfe6\xf2\xff\'~@}l\x88Y\xe0T\xa7\xb1\xa3\x1c\x9f;gL\xff\xf9C\xcb\xb4H\xa7\\\r\xb1\xac7\x01\xa5\xac\xce\xc9\x88}\xb3.\x8a\xc1"5\xe1\xd7E\x89\xa0\xffL\xc5\xed\x94\xd8\x94\xd5F\xa1\xbe6\x1a]'

# %%
b64='data:image/jpeg;base64,...'

# %%
b64Bytes=bytes(b64, 'ascii')

# %%
type(b64Bytes)
# Out:
# bytes

# %%
type(plain_data)
plain_data
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x01\x0b\x02N\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a
# ...

# %%
import base64
msg = base64.b64decode(plain_data)

# %%
msg
# Out:
# b'u\xabZ\x8af\xa0{\xf8\xe9z\x06\xda\xb1\xee\xb8\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x03\x02\x02\x03\x02\x02\x03\x03\x03\x03\x04\x03\x03\x04\x05\x08\x05\x05\x04\x04\x05\n\x07\x07\x06\x08\x0c\n\x0c\x0c\x0b\n\x0b\x0b\r\x0e\x12\x10\r\x0e\x11\x0e\x0b\x0b\x10\x16\x10\x11\x13\x14\x15\x15\x15\x0c\x0f\x17\x18\x16\x14\x18\x12\x14\x15\x14\xff\xdb\x00C\x01\x03\x04\x04\x05\x04\x05\t\x05\x05\t\x14\r\x0b\r\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\x14\xff\xc0\x00\x11\x08\x01\x0b\x02N\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1
# ...

# %%
plain_data.decode("ascii")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-71-7e427a96e4a1> in <module>
# ----> 1 plain_data.decode("ascii")
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xff in position 0: ordinal not in range(128)

# %%
plain_data
# Out:
# b'data:image/jpeg;base64,...'

# %%
type(plain_data)
# Out:
# bytes

# %%
type(key)
# Out:
# bytes

# %%
type(iv)
# Out:
# bytes
